# %% [markdown]
# # Chapter 1 :
#
# Naive Bayes

# %% [markdown]
# This uses NLTK Naive bayes Classifier. Three methods are used.
#
# 1. Naive Bayes (Unigram)
# 2. Naive Bayes with Stop words removed
# 3. Naive Bayes with Bigram
# 4. Naive Bayes with Bigram and Trigram

# %%
#input
import pandas as pd
import nltk
from nltk.corpus import treebank
x_test = []
y_test = []
p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
print len(p_test)
p_test.SentimentText
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
# Out:
# 60908

# %%
#input
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
def word_feats(words):
    return dict([(word, True) for word in words])

l = []
for f in range(len(p_test)):
    if p_test.Sentiment[f] == 0:
        l.append(f)

p = []
for f in range(len(p_test)):
    if p_test.Sentiment[f] == 1:
        p.append(f)        
print len(l)
print len(p)
# Out:
# 30592
# 30316

# %%
stop_words = []
negfeats = [(word_feats(x for x in p_test.SentimentText[f].lower().split() if x not in stop_words), 'neg') for f in l]
posfeats = [(word_feats(x for x in p_test.SentimentText[f].lower().split() if x not in stop_words), 'pos') for f in p]

trainfeats = negfeats+ posfeats
print len(trainfeats)

import random 
random.shuffle(trainfeats)
print(len(trainfeats))


p_train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')

l_t = []
for f in range(len(p_train)):
    if p_train.Sentiment[f] == 0:
        l_t.append(f)

p_t = []
for f in range(len(p_train)):
    if p_train.Sentiment[f] == 1:
        p_t.append(f)        
print len(l_t)
print len(p_t)
# Out:
# 60908
# 60908
# 22606
# 22226

# %% [markdown]
# ## Naive Bayes (Unigram)

# %%
stop_words = []
negfeatstest = [(word_feats(x for x in p_train.SentimentText[f].lower().split() if x not in stop_words), 'neg') for f in l_t]
posfeatstest = [(word_feats(x for x in p_train.SentimentText[f].lower().split() if x not in stop_words), 'pos') for f in p_t]

testfeats = negfeatstest + posfeatstest
points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output = []
for i in points:
    
    classifier = NaiveBayesClassifier.train(trainfeats[:i])
    out = nltk.classify.util.accuracy(classifier, testfeats)
    output.append(out)
    if i !=60908:
        del classifier
    print 'dataset: ',i, 'accuracy:', out



classifier.show_most_informative_features()

del classifier
#f = open("/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv").read()
#print f.strip().split(",")
# Out:
# dataset:  10 accuracy: 0.526275874375
# dataset:
#  50 accuracy: 0.57079764454
# dataset:
#  100 accuracy: 0.570819950036
# dataset:
#  500 accuracy: 0.619624375446
# dataset:
#  1000 accuracy: 0.647930049964
# dataset:
#  5000 accuracy: 0.692563347609
# dataset:
#  10000 accuracy: 0.708824054247
# dataset:
#  15000 accuracy: 0.713909707352
# dataset:
#  20000 accuracy: 0.720043718772
# dataset:
#  25000 accuracy: 0.723902569593
# dataset:
#  30000 accuracy: 0.72414793005
# dataset:
#  35000 accuracy: 0.724527123483
# dataset:
#  40000 accuracy: 0.726155424697
# dataset:
#  45000 accuracy: 0.728096002855
# dataset:
#  50000 accuracy: 0.729322805139
# dataset:
#  55000 accuracy: 0.731597965739
# dataset:
#  60000 accuracy: 0.733739293362
# dataset:
#  60908 accuracy: 0.734586902213
# Most Informative Features
#                   throat = True              neg : pos    =     52.5 : 1.0
#                     sad. = True              neg : pos    =     47.0 : 1.0
# ...

# %%
figsize(12.5,8)
plt.plot( points, output, color = "#348ABD", lw = 3 ) #
#plt.fill_between( p, p/(0.5+0.5*p), alpha = .5, facecolor = ["#A60628"]) 
#print 0.2/(0.4 + 0.4 * 0.2)
#plt.scatter( 0.2, 2*(0.2)/1.2, s = 140, c ="#348ABD" )
#plt.xlim( 0, 609080)
plt.ylim( 0, 1)
plt.xlabel( "Training size")
plt.ylabel("Naive bayes Accuracy")
plt.title( "Twitter Sentiment Accuracy over different datasize");

# %%
p = np.linspace( 0,60908, 100)

# %% [markdown]
# ## Naive Bayes with stop words removed

# %%
f = open("/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv").read()
stop_words = f.strip().split(",")
#not_words = ['neither', 'no', 'nor', 'not']
#for nw in not_words :
#    stop_words.remove(nw)

negfeatstest = [(word_feats(x for x in p_train.SentimentText[f].lower().split() if x not in stop_words), 'neg') for f in l_t]
posfeatstest = [(word_feats(x for x in p_train.SentimentText[f].lower().split() if x not in stop_words), 'pos') for f in p_t]

testfeats = negfeatstest + posfeatstest
points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output_2 = []
for i in points:
    
    classifier = NaiveBayesClassifier.train(trainfeats[:i])
    out = nltk.classify.util.accuracy(classifier, testfeats)
    output_2.append(out)
    if i !=60908:
        del classifier
    print 'dataset: ',i, 'accuracy:', out
del classifier
# Out:
# dataset:  10 accuracy: 0.520253390435
# dataset:
#  50 accuracy: 0.585028551035
# dataset:
#  100 accuracy: 0.595155246253
# dataset:
#  500 accuracy: 0.612620449679
# dataset:
#  1000 accuracy: 0.641952177016
# dataset:
#  5000 accuracy: 0.689596716631
# dataset:
#  10000 accuracy: 0.705723590293
# dataset:
#  15000 accuracy: 0.711054603854
# dataset:
#  20000 accuracy: 0.717657030692
# dataset:
#  25000 accuracy: 0.724370985011
# dataset:
#  30000 accuracy: 0.726266952177
# dataset:
#  35000 accuracy: 0.72767219843
# dataset:
#  40000 accuracy: 0.728452890792
# dataset:
#  45000 accuracy: 0.730393468951
# dataset:
#  50000 accuracy: 0.732847073519
# dataset:
#  55000 accuracy: 0.734720735189
# dataset:
#  60000 accuracy: 0.736482869379
# dataset:
#  60908 accuracy: 0.736728229836

# %%
figsize(12.5,8)
plt.plot( points, output, color = "#348ABD", lw = 3, label= "Naive Bayes (Unigram)" ) #
plt.plot( points,output_2, color = "#A60628", lw = 3, label= "Naive Bayes (Unigram) with stop words removed" )
#plt.fill_between( p, p/(0.5+0.5*p), alpha = .5, facecolor = ["#A60628"]) 
#print 0.2/(0.4 + 0.4 * 0.2)
#plt.scatter( 0.2, 2*(0.2)/1.2, s = 140, c ="#348ABD" )
#plt.xlim( 0, 609080)
plt.ylim( 0.4, 1)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Naive bayes Accuracy")
plt.title( "Twitter Sentiment Accuracy over different datasize");

# %%
def find_bigrams(input_list):
  bigram_list = []
  for i in range(len(input_list)-1):
      bigram_list.append((input_list[i], input_list[i+1]))
  return bigram_list

# %% [markdown]
# ## Naive Bayes with Bigram

# %%
stop_words = []
negfeats_2 = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'neg') for f in l]
posfeats_2 = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'pos') for f in p]

trainfeats_2 = negfeats_2+ posfeats_2
print len(trainfeats_2)

import random 
new_train = random.shuffle(trainfeats_2)



negfeatstest_2 = [(word_feats(x for x in p_train.SentimentText[f].lower().split() + find_bigrams(p_train.SentimentText[f].lower().split()) if x not in stop_words), 'neg') for f in l_t]
posfeatstest_2 = [(word_feats(x for x in p_train.SentimentText[f].lower().split() + find_bigrams(p_train.SentimentText[f].lower().split()) if x not in stop_words), 'pos') for f in p_t]

testfeats_2 = negfeatstest_2 + posfeatstest_2
random.shuffle(testfeats_2)
points_3 = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output_3 = []
for i in points_3:
    
    classifier = NaiveBayesClassifier.train(trainfeats_2[:i])
    out = nltk.classify.util.accuracy(classifier, testfeats_2)
    output_3.append(out)
    if i !=60908:
        del classifier
    print 'dataset: ',i, 'accuracy:', out



classifier.show_most_informative_features()
del classifier
# Out:
# 60908
# dataset:
#  10 accuracy: 0.546529264811
# dataset:
#  50 accuracy: 0.53954764454
# dataset:
#  100 accuracy: 0.56551124197
# dataset:
#  500 accuracy: 0.622702533904
# dataset:
#  1000 accuracy: 0.642710563883
# dataset:
#  5000 accuracy: 0.703292291221
# dataset:
#  10000 accuracy: 0.718616167024
# dataset:
#  15000 accuracy: 0.725240899358
# dataset:
#  20000 accuracy: 0.729122055675
# dataset:
#  25000 accuracy: 0.736772840828
# dataset:
#  30000 accuracy: 0.739627944325
# dataset:
#  35000 accuracy: 0.74346448965
# dataset:
#  40000 accuracy: 0.745895788722
# dataset:
#  45000 accuracy: 0.75
# dataset:
#  50000 accuracy: 0.75176213419
# dataset:
#  55000 accuracy: 0.749643112063
# dataset:
#  60000 accuracy: 0.751583690221
# dataset:
#  60908 accuracy: 0.75124910778
# Most Informative Features
#                   throat = True              neg : pos    =     52.5 : 1.0
#                     sad. = True              neg : pos    =     47.0 : 1.0
# ...

# %%
from ipy_table import *
data_table = [
    ['Training Size', 'Naive Bayes Bigram Accuracy'],
    ];
for i in range(len(output_3)) :
    data_table.append([points[i],output_3[i]])

make_table(data_table)
apply_theme('basic')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbspBigram&nbspAccuracy</b></td></tr><tr><td  style="background-color:Ivory;">10</td><td  style="background-color:Ivory;">0.5465</td></tr><tr><td  style="background-color:AliceBlue;">50</td><td  style="background-color:AliceBlue;">0.5395</td></tr><tr><td  style="background-color:Ivory;">100</td><td  style="background-color:Ivory;">0.5655</td></tr><tr><td  style="background-color:AliceBlue;">500</td><td  style="background-color:AliceBlue;">0.6227</td></tr><tr><td  style="background-color:Ivory;">1000</td><td  style="background-color:Ivory;">0.6427</td></tr><tr><td  style="background-color:AliceBlue;">5000</td><td  style="background-color:AliceBlue;">0.7033</td></tr><tr><td  style="background-color:Ivory;">10000</td><td  style="background-color:Ivo
# ...

# %%
figsize(12.5,8)
plt.plot( points, output, color = "#348ABD", lw = 3, label= "Naive Bayes (Unigram)" ) #
plt.plot( points,output_2, color = "#A60628", lw = 3, label= "Naive Bayes (Unigram) with stop words removed" )
plt.plot( points_3,output_3, color = "#7A68A6", lw = 3, label= "Naive Bayes (Bigram)" )

#plt.fill_between( points, output, alpha = .1, facecolor = ["#348ABD"]) 
#plt.fill_between( points_2, output_2, alpha = .1, facecolor = ["#A60628"]) 
#plt.fill_between( points_3, output_3, alpha = .1, facecolor = ["#7A68A6"]) 
plt.ylim( 0.4, 1)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Naive bayes Accuracy")
plt.title( "Twitter Sentiment Accuracy over different training datasize");

# %% [markdown]
# ## Naive Bayes with bigram and trigram

# %%
#input
stop_words = []
negfeats_2 = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) + zip(p_test.SentimentText[f].lower().split(),p_test.SentimentText[f].lower().split()[1:],p_test.SentimentText[f].lower().split()[2:]) if x not in stop_words), 'neg') for f in l]
posfeats_2 = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split())+ zip(p_test.SentimentText[f].lower().split(),p_test.SentimentText[f].lower().split()[1:],p_test.SentimentText[f].lower().split()[2:]) if x not in stop_words), 'pos') for f in p]

trainfeats_2 = negfeats_2+ posfeats_2
print len(trainfeats_2)

import random 
random.shuffle(trainfeats_2)



negfeatstest_2 = [(word_feats(x for x in p_train.SentimentText[f].lower().split() + find_bigrams(p_train.SentimentText[f].lower().split())+ zip(p_train.SentimentText[f].lower().split(),p_train.SentimentText[f].lower().split()[1:],p_train.SentimentText[f].lower().split()[2:]) if x not in stop_words), 'neg') for f in l_t]
posfeatstest_2 = [(word_feats(x for x in p_train.SentimentText[f].lower().split() + find_bigrams(p_train.SentimentText[f].lower().split())+ zip(p_train.SentimentText[f].lower().split(),p_train.SentimentText[f].lower().split()[1:],p_train.SentimentText[f].lower().split()[2:]) if x not in stop_words), 'pos') for f in p_t]

testfeats_2 = negfeatstest_2 + posfeatstest_2
points_3 = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output_4 = []
for i in points_3:
    
    classifier = NaiveBayesClassifier.train(trainfeats_2[:i])
    out = nltk.classify.util.accuracy(classifier, testfeats_2)
    if i !=60908:
        del classifier
    output_4.append(out)
    print 'dataset: ',i, 'accuracy:', out



classifier.show_most_informative_features()
# Out:
# 60908
# dataset:
#  10 accuracy: 0.495873483226
# dataset:
#  50 accuracy: 0.548492148465
# dataset:
#  100 accuracy: 0.573786581014
# dataset:
#  500 accuracy: 0.625981441827
# dataset:
#  1000 accuracy: 0.641059957173
# dataset:
#  5000 accuracy: 0.704764453961
# dataset:
#  10000 accuracy: 0.716742505353
# dataset:
#  15000 accuracy: 0.725664703783
# dataset:
#  20000 accuracy: 0.732356352605
# dataset:
#  25000 accuracy: 0.736259814418
# dataset:
#  30000 accuracy: 0.739471805853
# dataset:
#  35000 accuracy: 0.741992326909
# dataset:
#  40000 accuracy: 0.744245182013
# dataset:
#  45000 accuracy: 0.746297287652
# dataset:
#  50000 accuracy: 0.746698786581
# dataset:
#  55000 accuracy: 0.750066916488
# dataset:
#  60000 accuracy: 0.751092969308
# dataset:
#  60908 accuracy: 0.751918272662
# Most Informative Features
#  ('sorry', 'to', 'hear') = True              neg : pos    =     69.7 : 1.0
#                   throat = True              neg : pos    =     52.5 : 1.0
# ...

# %%
del classifier

# %%
#input
figsize(12.5,8)
plt.plot( points, output, color = "#348ABD", lw = 3, label= "Naive Bayes (Unigram)" ) #
plt.plot( points,output_2, color = "#A60628", lw = 3, label= "Naive Bayes (Unigram) with stop words removed" )
plt.plot( points_3,output_3, color = "#7A68A6", lw = 3, label= "Naive Bayes (Bigram)" )
plt.plot( points_3,output_4, color = "#467821", lw = 3, label= "Naive Bayes (Bigram + Trigram)" )
#plt.fill_between( points, output, alpha = .1, facecolor = ["#348ABD"]) 
#plt.fill_between( points_2, output_2, alpha = .1, facecolor = ["#A60628"]) 
#plt.fill_between( points_3, output_3, alpha = .1, facecolor = ["#7A68A6"]) 
plt.ylim( 0.4, 1)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Naive bayes Accuracy")
plt.title( "Twitter Sentiment Accuracy over different training datasize");

# %%
negfeatstest = [(word_feats(x for x in p_train.SentimentText[f].lower().split() if x not in stop_words), 'neg') for f in l_t]
posfeatstest = [(word_feats(x for x in p_train.SentimentText[f].lower().split() if x not in stop_words), 'pos') for f in p_t]

testfeats = negfeatstest + posfeatstest
new_test = random.shuffle(testfeats)

# %%
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
y = []
x = linspace(0.01,0.06,10)
for c in x:
    classif = SklearnClassifier(LinearSVC(C=c))
    classif.train(trainfeats)
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    y.append( nltk.classify.util.accuracy(classif, testfeats))
    #print y[-1]
figure()
plot(x, y, color = "#A60628", lw = 3)
xlabel('C Value')
ylabel('Accuracy')
title('C Value Vs Accuracy')
show()

# %%
points_3 = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output_5 = []
for i in points_3:
    
    classif = SklearnClassifier(LinearSVC(C=0.06))
    classif.train(trainfeats[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeats)
    if i !=60908:
        del classif
    output_5.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.525450571021
# .
# dataset:  50 accuracy: 0.550521948608
# .
# dataset:  100 accuracy: 0.569726980728
# .
# dataset:  500 accuracy: 0.6261375803
# .
# dataset:  1000 accuracy: 0.660421127766
# .
# dataset:  5000 accuracy: 0.726222341185
# .
# dataset:  10000 accuracy: 0.739806388294
# .
# dataset:  15000 accuracy: 0.748973947181
# .
# dataset:  20000 accuracy: 0.75426034975
# .
# dataset:  25000 accuracy: 0.758096895075
# .
# dataset:  30000 accuracy: 0.76130888651
# .
# dataset:  35000 accuracy: 0.762847965739
# .
# dataset:  40000 accuracy: 0.76556923626
# .
# dataset:  45000 accuracy: 0.766862955032
# .
# dataset:  50000 accuracy: 0.769807280514
# .
# dataset:  55000 accuracy: 0.771413276231
# .
# dataset:  60000 accuracy: 0.770699500357
# .
# dataset:  60908 accuracy: 0.771257137759

# %%
figsize(12.5,8)
plt.plot( points_3, output_5, color = "#0d7074", lw = 3, label= "Linear SVC (Unigram)" ) #
plt.plot( points, output, color = "#348ABD", lw = 3, label= "Naive Bayes (Unigram)" ) #
plt.plot( points,output_2, color = "#A60628", lw = 3, label= "Naive Bayes (Unigram) with stop words removed" )
plt.plot( points,output_3, color = "#7A68A6", lw = 3, label= "Naive Bayes (Bigram)" )
#plt.plot( points,output_4, color = "#467821", lw = 3, label= "Naive Bayes (Bigram + Trigram)" )
#plt.fill_between( points, output, alpha = .1, facecolor = ["#348ABD"]) 
#plt.fill_between( points_2, output_2, alpha = .1, facecolor = ["#A60628"]) 
#plt.fill_between( points_3, output_3, alpha = .1, facecolor = ["#7A68A6"]) 
plt.ylim( 0.4, 1)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Accuracy")
plt.title( "Twitter Sentiment Accuracy over different training datasize");

# %%
points_3 = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output_6 = []
from sklearn.svm import LinearSVC
for i in points_3:
    
    classif = SklearnClassifier(LinearSVC(C=0.06))
    classif.train(trainfeats_2[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeats_2)
    if i !=60908:
        del classif
    output_6.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.500223054961
# .
# dataset:  50 accuracy: 0.574232690935
# .
# dataset:  100 accuracy: 0.56437366167
# .
# dataset:  500 accuracy: 0.632293897216
# .
# dataset:  1000 accuracy: 0.657989828694
# .
# dataset:  5000 accuracy: 0.725486259814
# .
# dataset:  10000 accuracy: 0.746609564597
# .
# dataset:  15000 accuracy: 0.756468593862
# .
# dataset:  20000 accuracy: 0.761487330478
# .
# dataset:  25000 accuracy: 0.767375981442
# .
# dataset:  30000 accuracy: 0.771011777302
# .
# dataset:  35000 accuracy: 0.77210474661
# .
# dataset:  40000 accuracy: 0.775941291934
# .
# dataset:  45000 accuracy: 0.777324232691
# .
# dataset:  50000 accuracy: 0.778171841542
# .
# dataset:  55000 accuracy: 0.780714668094
# .
# dataset:  60000 accuracy: 0.782476802284
# .
# dataset:  60908 accuracy: 0.782855995717

# %%
figsize(12.5,8)
plt.plot( points_3, output_5, color = "#0d7074", lw = 3, label= "Linear SVC (Unigram)" ) #
plt.plot( points_3, output_6, color = "#440000", lw = 3, label= "Linear SVC (Unigram + Bigram)" ) #
plt.plot( points, output, color = "#348ABD", lw = 3, label= "Naive Bayes (Unigram)" ) #
plt.plot( points,output_2, color = "#A60628", lw = 3, label= "Naive Bayes (Unigram) with stop words removed" )
plt.plot( points,output_3, color = "#7A68A6", lw = 3, label= "Naive Bayes (Bigram)" )
#plt.plot( points,output_4, color = "#467821", lw = 3, label= "Naive Bayes (Bigram + Trigram)" )
#plt.fill_between( points, output, alpha = .1, facecolor = ["#348ABD"]) 
#plt.fill_between( points_2, output_2, alpha = .1, facecolor = ["#A60628"]) 
#plt.fill_between( points_3, output_3, alpha = .1, facecolor = ["#7A68A6"]) 
plt.ylim( 0.4, 1)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Accuracy")
plt.title( "Twitter Sentiment Accuracy over different training datasize");

# %%
from ipy_table import *
data_table = [
    ['Training Size', 'Naive Bayes \n(Unigram)','Naive Bayes(Unigram)\nwithout stopwords',
     'Naive Bayes \n(Bigram)','Naive Bayes \n(Bigram + Trigram)','Linear SVC \n(Unigram)','Linear SVC \n(Unigram + Bigram)'],
    ];
for i in range(len(output_3)) :
    data_table.append([points[i],output[i],output_2[i],output_3[i],output_4[i],output_5[i],output_6[i]])

make_table(data_table)

apply_theme('basic')
set_row_style(18,color='orange')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes(Unigram)
# without&nbspstopwords</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram&nbsp+&nbspTrigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# ...

# %%
# using stemming and naive bayes... Training on trainSA.csv and tseting on TestSA.csv
import pandas as pd
import nltk
import scipy as sp
from nltk.classify import NaiveBayesClassifier
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()

p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')
train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
stopwords = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv')
def word_feats(words):
    return dict([(word, True) for word in words])


for i in range(len(train)-1):
    t = []
    for word in nltk.word_tokenize(train.SentimentText[i]):
        t.append(stemmer.stem(word))

    train.SentimentText[i] = " ".join(t)
neg_tw = []
pos_tw = []
for i in range(len(train)):
    if train.Sentiment[i] == '0':
        neg_tw.append(i)
    else:
        pos_tw.append(i)
nf = [(word_feats(x for x in train.SentimentText[f].lower().split()  if x not in stopwords), 'neg') for f in neg_tw]
pf = [(word_feats(x for x in train.SentimentText[f].lower().split() if x not in stopwords), 'pos') for f in pos_tw]

trainf = nf + pf
import random 
random.shuffle(trainf)

#test data

for i in range(len(p_test)):
    t = []
    for word in nltk.word_tokenize(p_test.SentimentText[i]):
        t.append(stemmer.stem(word))

    p_test.SentimentText[i] = " ".join(t)
neg_tweets_test = []
pos_tweets_test = []
for i in range(len(p_test)):
    if p_test.Sentiment[i] == 0:
        neg_tweets_test.append(i)
    else:
        pos_tweets_test.append(i)
        
negfeatstest = [(word_feats(x for x in  p_test.SentimentText[f].lower().split() if x not in stopwords), 'neg') for f in neg_tweets_test]
posfeatstest = [(word_feats(x for x in  p_test.SentimentText[f].lower().split() if x not in stopwords), 'pos') for f in pos_tweets_test]
testfeats = negfeatstest + posfeatstest
import random 
random.shuffle(testfeats)
accuracy_1 = []
for i in points:
    classifier = NaiveBayesClassifier.train(trainf[:i])
    print 'train on %d instances, test on %d instances' % (len(trainf[:i]), len(testfeats))
    print nltk.classify.util.accuracy(classifier, testfeats)
    accuracy_1.append(nltk.classify.util.accuracy(classifier, testfeats))
# Out:
# train on 10 instances, test on 44832 instances
# 0.511398108494
# train on 50 instances, test on 44832 instances
# 0.585073162027
# train on 100 instances, test on 44832 instances
# 0.597452712348
# train on 500 instances, test on 44832 instances
# 0.650918986438
# train on 1000 instances, test on 44832 instances
# 0.677395610278
# train on 5000 instances, test on 44832 instances
# 0.715582619557
# train on 10000 instances, test on 44832 instances
# 0.728207530335
# train on 15000 instances, test on 44832 instances
# 0.733538543897
# train on 20000 instances, test on 44832 instances
# 0.738021948608
# train on 25000 instances, test on 44832 instances
# 0.740252498216
# train on 30000 instances, test on 44832 instances
# 0.742572269807
# train on 35000 instances, test on 44832 instances
# 0.744557458958
# train on 40000 instances, test on 44832 instances
# 0.746408815132
# train on 45000 instances, test on 44832 instances
# 0.749821556031
# ...

# %%
data_table = [
    ['Training Size', 'Naive Bayes \n(Unigram)','Naive Bayes(Unigram)\nwithout stopwords',
     'Naive Bayes \n(Bigram)','Naive Bayes \n(Bigram + Trigram)','Linear SVC \n(Unigram)','Linear SVC \n(Unigram + Bigram)','Naive Bayes \n(Unigram) Stem'],
    ];
for i in range(len(output_3)) :
    data_table.append([points[i],output[i],output_2[i],output_3[i],output_4[i],output_5[i],output_6[i],accuracy_1[i]])

make_table(data_table)

apply_theme('basic')
set_row_style(18,color='orange')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes(Unigram)
# without&nbspstopwords</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram&nbsp+&nbspTrigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram&nbsp+&nbspBigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# ...

# %%
figsize(12.5,8)
plt.plot( points_3, output_5, color = "#0d7074", lw = 3, label= "Linear SVC (Unigram)" ) #
plt.plot( points_3, output_6, color = "#440000", lw = 3, label= "Linear SVC (Unigram + Bigram)" ) #
plt.plot( points, output, color = "#348ABD", lw = 3, label= "Naive Bayes (Unigram)" ) #
plt.plot( points,output_2, color = "#A60628", lw = 3, label= "Naive Bayes (Unigram) with stop words removed" )
plt.plot( points,output_3, color = "#7A68A6", lw = 3, label= "Naive Bayes (Bigram)" )
plt.plot( points,output_4, color = "#467821", lw = 3, label= "Naive Bayes (Bigram + Trigram)" )
plt.plot( points,accuracy_1, color = "#368000", lw = 3, label= "Naive Bayes Stemmed" )
#plt.fill_between( points, output, alpha = .1, facecolor = ["#348ABD"]) 
#plt.fill_between( points_2, output_2, alpha = .1, facecolor = ["#A60628"]) 
#plt.fill_between( points_3, output_3, alpha = .1, facecolor = ["#7A68A6"]) 
plt.ylim( 0.4, 1)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Accuracy")
plt.title( "Twitter Sentiment Accuracy over different training datasize");

# %%
# naive bayes + stemming + bigram

def find_bigrams(input_list):
  bigram_list = []
  for i in range(len(input_list)-1):
      bigram_list.append((input_list[i], input_list[i+1]))
  return bigram_list
    
    
negfeats_2 = [(word_feats(x for x in train.SentimentText[f].lower().split() + find_bigrams(train.SentimentText[f].lower().split()) if x not in stopwords), 'neg') for f in neg_tw]
posfeats_2 = [(word_feats(x for x in train.SentimentText[f].lower().split() + find_bigrams(train.SentimentText[f].lower().split()) if x not in stopwords), 'pos') for f in pos_tw]

trainfeats_2 = negfeats_2+ posfeats_2
print len(trainfeats_2)

import random 
new_train = random.shuffle(trainfeats_2)



negfeatstest_2 = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'neg') for f in neg_tweets_test]
posfeatstest_2 = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'pos') for f in pos_tweets_test]

testfeats_2 = negfeatstest_2 + posfeatstest_2
random.shuffle(testfeats_2)
accuracy_2 = []
for i in points:
    classifier = NaiveBayesClassifier.train(trainfeats_2[:i])
    out = nltk.classify.util.accuracy(classifier, testfeats_2)
    accuracy_2.append(out)
    if i !=60908:
        del classifier
    sys.stdout.write('.')
    #print 'dataset: ',i, 'accuracy:', out
# Out:
# 60909
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .

# %%
data_table = [
    ['Training Size', 'Naive Bayes \n(Unigram)','Naive Bayes(Unigram)\nwithout stopwords',
     'Naive Bayes \n(Bigram)','Naive Bayes \n(Bigram + Trigram)','Linear SVC \n(Unigram)',
     'Linear SVC \n(Unigram + Bigram)','Naive Bayes \n(Unigram) Stem', 'Naive Bayes \n Bigram Stem'],
    ];
for i in range(len(output_3)) :
    data_table.append([points[i],output[i],output_2[i],output_3[i],output_4[i],
                       output_5[i],output_6[i],accuracy_1[i], accuracy_2[i]])

make_table(data_table)

apply_theme('basic')
set_row_style(18,color='orange')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes(Unigram)
# without&nbspstopwords</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram&nbsp+&nbspTrigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram&nbsp+&nbspBigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)&nbspStem</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# ...

# %%
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy_3 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainf[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeats)
    if i !=60908:
        del classif
    accuracy_3.append(out)
    import sys
    sys.stdout.write('.')
    #print 'dataset: ',i, 'accuracy:', out
# Out:
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..

# %%
data_table = [
    ['Training Size', 'Naive Bayes \n(Unigram)','Naive Bayes(Unigram)\nwithout stopwords',
     'Naive Bayes \n(Bigram)','Naive Bayes \n(Bigram + Trigram)','Linear SVC \n(Unigram)',
     'Linear SVC \n(Unigram + Bigram)','Naive Bayes \n(Unigram) Stem', 'Naive Bayes \n Bigram Stem', 
     'Linear SVC \n(Unigram) Stem'],
    ];
for i in range(len(output_3)) :
    data_table.append([points[i],output[i],output_2[i],output_3[i],output_4[i],
                       output_5[i],output_6[i],accuracy_1[i], accuracy_2[i], accuracy_3[i]])

make_table(data_table)

apply_theme('basic')
set_row_style(18,color='orange')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes(Unigram)
# without&nbspstopwords</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram&nbsp+&nbspTrigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram&nbsp+&nbspBigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)&nbspStem</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# &nbspBigram&nbspStem</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# ...

# %%
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy_4 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeats_2[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeats_2)
    if i !=60908:
        del classif
    accuracy_4.append(out)
    import sys
    sys.stdout.write('.')
    #print 'dataset: ',i, 'accuracy:', out
# Out:
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..

# %%
data_table = [
    ['Training Size', 'Naive Bayes \n(Unigram)','Naive Bayes(Unigram)\nwithout stopwords',
     'Naive Bayes \n(Bigram)','Naive Bayes \n(Bigram + Trigram)','Linear SVC \n(Unigram)',
     'Linear SVC \n(Unigram + Bigram)','Naive Bayes \n(Unigram) Stem', 'Naive Bayes \n Bigram Stem', 
     'Linear SVC \n(Unigram) Stem','Linear SVC \n(Bigram) Stem'],
    ];
for i in range(len(output_3)) :
    data_table.append([points[i],output[i],output_2[i],output_3[i],output_4[i],
                       output_5[i],output_6[i],accuracy_1[i], accuracy_2[i], accuracy_3[i],
                        accuracy_4[i]])

make_table(data_table)

apply_theme('basic')
set_row_style(18,color='orange')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes(Unigram)
# without&nbspstopwords</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Bigram&nbsp+&nbspTrigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram)</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# (Unigram&nbsp+&nbspBigram)</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# (Unigram)&nbspStem</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbsp
# &nbspBigram&nbspStem</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbsp
# ...

# %%
import pandas as pd
import nltk
import scipy as sp
from nltk.classify import NaiveBayesClassifier
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
from nltk.tag.simplify import simplify_wsj_tag

p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')
train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
stopwords = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv')

def word_feats(words):
    return dict([(word, True) for word in words])


for i in range(len(train)):
    t = []
    for word in nltk.word_tokenize(train.SentimentText[i]):
        t.append(stemmer.stem(word))

    train.SentimentText[i] = " ".join(t)
neg_tw = []
pos_tw = []
for i in range(len(train)):
    if train.Sentiment[i] == 0:
        neg_tw.append(i)
    else:
        pos_tw.append(i)
    
    
negfeatspos = []
posfeatspos = []
for f in range(len(train)):
    if f in neg_tw:
        negfeatspos.append(([(word, simplify_wsj_tag(tag)) for word, tag in nltk.pos_tag(nltk.word_tokenize(train.SentimentText[f].lower()))], 'neg')) 
    else:
        posfeatspos.append(([(word, simplify_wsj_tag(tag)) for word, tag in nltk.pos_tag(nltk.word_tokenize(train.SentimentText[f].lower()))], 'pos')) 
    
trainfeatspos = negfeatspos+ posfeatspos
print len(trainfeatspos)

import random 
new_train = random.shuffle(trainfeatspos)

for i in range(len(p_test)):
    t = []
    for word in nltk.word_tokenize(p_test.SentimentText[i]):
        t.append(stemmer.stem(word))

    p_test.SentimentText[i] = " ".join(t)
neg_tweets_test = []
pos_tweets_test = []
for i in range(len(p_test)):
    if p_test.Sentiment[i] ==0:
        neg_tweets_test.append(i)
    else:
        pos_tweets_test.append(i)

#negfeatstestpos = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'neg') for f in neg_tweets_test]
#posfeatstest = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'pos') for f in pos_tweets_test]
negfeatstestpos = []
posfeatstestpos = []
for f in range(len(p_test)):
    if f in neg_tweets_test:
        negfeatstestpos.append(([(word, simplify_wsj_tag(tag)) for word, tag in nltk.pos_tag(nltk.word_tokenize(p_test.SentimentText[f].lower()))], 'neg')) 
    else:
        posfeatstestpos.append(([(word, simplify_wsj_tag(tag)) for word, tag in nltk.pos_tag(nltk.word_tokenize(p_test.SentimentText[f].lower()))], 'pos')) 
 
testfeatspos = negfeatstestpos + posfeatstestpos
random.shuffle(testfeatspos)
print len(testfeatspos)
# Out:
# 60908
# 44832

# %%
trainfeattrue = []
for a in trainfeatspos:
    trainfeattrue.append((dict((k,True) for k in a[0]), a[1]))
    
testfeattrue = []
for a in testfeatspos:
    testfeattrue.append((dict((k,True) for k in a[0]), a[1]))

# %%
trainfeattrue[0]
# Out:
# ({('all', 'DET'): True,
#   ('back', 'ADV'): True,
#   ('befor', 'P'): True,
#   ('it', 'PRO'): True,
#   ('take', 'V'): True,
#   ('to', 'TO'): True,
#   ('tri', 'N'): True,
#   ('went', 'N'): True,
#   ('wrong', 'P'): True},
#  'pos')

# %%
points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy_6 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeattrue[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeattrue)
    if i !=60908:
        del classif
    accuracy_6.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.510728943612
# .
# dataset:  50 accuracy: 0.519361170592
# .
# dataset:  100 accuracy: 0.606575660243
# .
# dataset:  500 accuracy: 0.656049250535
# .
# dataset:  1000 accuracy: 0.673492148465
# .
# dataset:  5000 accuracy: 0.72425945753
# .
# dataset:  10000 accuracy: 0.744423625981
# .
# dataset:  15000 accuracy: 0.752163633119
# .
# dataset:  20000 accuracy: 0.756401677373
# .
# dataset:  25000 accuracy: 0.761375802998
# .
# dataset:  30000 accuracy: 0.765301570307
# .
# dataset:  35000 accuracy: 0.766862955032
# .
# dataset:  40000 accuracy: 0.769138115632
# .
# dataset:  45000 accuracy: 0.771390970735
# .
# dataset:  50000 accuracy: 0.773153104925
# .
# dataset:  55000 accuracy: 0.775517487509
# .
# dataset:  60000 accuracy: 0.776387401856
# .
# dataset:  60908 accuracy: 0.776811206281

# %%
from ipy_table import *
data_table = [
    ['Training Size', 'Linear SVC POS Accuracy'],
    ];
for i in range(len(accuracy_6)) :
    data_table.append([points[i],accuracy_6[i]])

make_table(data_table)
apply_theme('basic')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbspPOS&nbspAccuracy</b></td></tr><tr><td  style="background-color:Ivory;">10</td><td  style="background-color:Ivory;">0.5107</td></tr><tr><td  style="background-color:AliceBlue;">50</td><td  style="background-color:AliceBlue;">0.5194</td></tr><tr><td  style="background-color:Ivory;">100</td><td  style="background-color:Ivory;">0.6066</td></tr><tr><td  style="background-color:AliceBlue;">500</td><td  style="background-color:AliceBlue;">0.6560</td></tr><tr><td  style="background-color:Ivory;">1000</td><td  style="background-color:Ivory;">0.6735</td></tr><tr><td  style="background-color:AliceBlue;">5000</td><td  style="background-color:AliceBlue;">0.7243</td></tr><tr><td  style="background-color:Ivory;">10000</td><td  style="background-color:Ivory;"
# ...

# %%
trainfeattrue_2 = []
for a in trainfeatspos:
    trainfeattrue_2.append(((dict((k,True) for k in a[0]+zip(a[0],a[0][1:]) )),a[1]))
    
    

testfeattrue_2 = []
for a in testfeatspos:
    testfeattrue_2.append(((dict((k,True) for k in a[0]+zip(a[0],a[0][1:]) )),a[1]))

# %%
points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy_7 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeattrue_2[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeattrue_2)
    if i !=60908:
        del classif
    accuracy_7.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.506736259814
# .
# dataset:  50 accuracy: 0.511978051392
# .
# dataset:  100 accuracy: 0.607289436117
# .
# dataset:  500 accuracy: 0.65562544611
# .
# dataset:  1000 accuracy: 0.673536759458
# .
# dataset:  5000 accuracy: 0.725999286224
# .
# dataset:  10000 accuracy: 0.74687723055
# .
# dataset:  15000 accuracy: 0.758141506067
# .
# dataset:  20000 accuracy: 0.76380710207
# .
# dataset:  25000 accuracy: 0.769249643112
# .
# dataset:  30000 accuracy: 0.770900249822
# .
# dataset:  35000 accuracy: 0.774892933619
# .
# dataset:  40000 accuracy: 0.777324232691
# .
# dataset:  45000 accuracy: 0.780714668094
# .
# dataset:  50000 accuracy: 0.782342969308
# .
# dataset:  55000 accuracy: 0.784595824411
# .
# dataset:  60000 accuracy: 0.786112598144
# .
# dataset:  60908 accuracy: 0.786291042113

# %%
trainfeattrue_2[0]
# Out:
# ({('all', 'DET'): True,
#   ('back', 'ADV'): True,
#   ('befor', 'P'): True,
#   ('it', 'PRO'): True,
#   ('take', 'V'): True,
#   ('to', 'TO'): True,
#   ('tri', 'N'): True,
#   ('went', 'N'): True,
#   ('wrong', 'P'): True,
#   (('all', 'DET'), ('went', 'N')): True,
#   (('back', 'ADV'), ('befor', 'P')): True,
#   (('befor', 'P'), ('it', 'PRO')): True,
#   (('it', 'PRO'), ('all', 'DET')): True,
#   (('it', 'PRO'), ('back', 'ADV')): True,
#   (('take', 'V'), ('it', 'PRO')): True,
#   (('to', 'TO'), ('take', 'V')): True,
#   (('tri', 'N'), ('to', 'TO')): True,
#   (('went', 'N'), ('wrong', 'P')): True},
#  'pos')

# %%
from ipy_table import *
data_table = [
    ['Training Size', 'Linear SVC POS Accuracy', 'Linear SVC POS + Bigram'],
    ];
for i in range(len(accuracy_6)) :
    data_table.append([points[i],accuracy_6[i],accuracy_7[i]])

make_table(data_table)
apply_theme('basic')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbspPOS&nbspAccuracy</b></td><td  style="background-color:LightGray;"><b>Linear&nbspSVC&nbspPOS&nbsp+&nbspBigram</b></td></tr><tr><td  style="background-color:Ivory;">10</td><td  style="background-color:Ivory;">0.5107</td><td  style="background-color:Ivory;">0.5067</td></tr><tr><td  style="background-color:AliceBlue;">50</td><td  style="background-color:AliceBlue;">0.5194</td><td  style="background-color:AliceBlue;">0.5120</td></tr><tr><td  style="background-color:Ivory;">100</td><td  style="background-color:Ivory;">0.6066</td><td  style="background-color:Ivory;">0.6073</td></tr><tr><td  style="background-color:AliceBlue;">500</td><td  style="background-color:AliceBlue;">0.6560</td><td  style="background-color:AliceBlue;">0.6556</td></tr><tr><td  
# ...

# %%
#p_test = pd.read_csv('/Users/girishsk/Documents/Shachi/Machine learning/Assignments/Project/TestSA.csv')
#train = pd.read_csv('/Users/girishsk/Documents/Shachi/Machine learning/Assignments/Project/TrainSA.csv')
featuretrain = []
traintarget = []
trainlist = []
for i in range(len(train)):
      featuretrain.append([len(train.SentimentText[i])])
      traintarget.append(train.Sentiment[i])
      trainlist.append([featuretrain[i],traintarget[i]])

featuretest = []
testlist = []
testtarget = []
for i in range(len(p_test)):
      featuretest.append([len(p_test.SentimentText[i])])
      testtarget.append(p_test.Sentiment[i])
      testlist.append([featuretest[i],testtarget[i]])

from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn import svm
clf = svm.LinearSVC()
clf.fit(featuretrain,traintarget)
y = clf.predict(featuretest)
#classif = SklearnClassifier(LinearSVC(C=0.032))
#classif.train(trainlist)
#print 'train on %d instances, test on %d instances' % (len(trainlist), len(testlist))
#y.append( nltk.classify.util.accuracy(classif, testlist))
print y

mistakes = 0
for i in range(len(p_test)):
    if p_test.Sentiment[i] != y[i]:
        mistakes = mistakes + 1
print mistakes
# Out:
# [1 1 1 ..., 1 1 1]
# 22606

# %%
pos = []
neg = []
for i in range(len(featuretrain)):
    if traintarget[i] == 0:
        neg.append(featuretrain[i][0])
    else:
        pos.append(featuretrain[i][0])

        
    
    
figsize(12.5,8)
plt.scatter( range(len(neg)),neg ,color = "#0d7074", lw = 3,alpha = .4, label= "Neg words" ) #
plt.scatter( range(len(pos)),pos ,color = "#A60628", lw = 3, alpha = .4, label= "Pos words" ) #

#plt.fill_between( points, output, alpha = .1, facecolor = ["#348ABD"]) 
#plt.fill_between( points_2, output_2, alpha = .1, facecolor = ["#A60628"]) 
#plt.fill_between( points_3, output_3, alpha = .1, facecolor = ["#7A68A6"]) 
plt.ylim( 0, 500)
plt.xlabel( "Training size")
leg = plt.legend()
leg.get_frame().set_alpha(0.1)
plt.ylabel("Accuracy")
plt.title( "Length of tweet and sentiments");

# %%
featuretrain = []
traintarget = []
trainlist = []
for i in range(len(train)):
      featuretrain.append([len(train.SentimentText[i]),
                          train.SentimentText[i].count('!'),
                          train.SentimentText[i].count(' not'),
                          train.SentimentText[i].count('\'nt'),
                          train.SentimentText[i].count('&')])
      traintarget.append(train.Sentiment[i])
      trainlist.append([featuretrain[i],traintarget[i]])

featuretest = []
testlist = []
testtarget = []
for i in range(len(p_test)):
      featuretest.append([len(p_test.SentimentText[i]),
                          p_test.SentimentText[i].count('!'),
                          p_test.SentimentText[i].count(' not'),
                          p_test.SentimentText[i].count('\'nt'),
                          p_test.SentimentText[i].count('&')])
      testtarget.append(p_test.Sentiment[i])
      testlist.append([featuretest[i],testtarget[i]])

from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn import svm
clf = svm.LinearSVC()
clf.fit(featuretrain,traintarget)
y = clf.predict(featuretest)
#classif = SklearnClassifier(LinearSVC(C=0.032))
#classif.train(trainlist)
#print 'train on %d instances, test on %d instances' % (len(trainlist), len(testlist))
#y.append( nltk.classify.util.accuracy(classif, testlist))
print y

mistakes = 0
for i in range(len(p_test)):
    if p_test.Sentiment[i] != y[i]:
        mistakes = mistakes + 1
print mistakes
print float(len(testtarget) - mistakes)/len(testtarget)
# Out:
# [0 0 0 ..., 0 0 0]
# 22216
# 0.504461099215

# %%
s = 'hello world'

# %%
s.count('l')
# Out:
# 3

# %%
import nltk.classify.util
from nltk.classify import MaxentClassifier
algorithm = nltk.classify.MaxentClassifier.ALGORITHMS[0]

points_3 = [60908]
amax = []
for i in points_3:
    classifier = nltk.MaxentClassifier.train(trainfeattrue[:i],algorithm, max_iter=10)
    out_maxent_uni = nltk.classify.util.accuracy(classifier, testfeattrue)
    amax.append(out_maxent_uni)
    print 'dataset: ',i, 'accuracy:', out_maxent_uni
classifier.show_most_informative_features()
del classifier
# Out:
#   ==> Training (10 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.498
#              2          -0.69313        0.871
#              3          -0.69311        0.871
#              4          -0.69310        0.871
#              5          -0.69308        0.871
#              6          -0.69306        0.871
#              7          -0.69305        0.871
#              8          -0.69303        0.871
#              9          -0.69301        0.871
#          Final          -0.69299        0.871
# dataset:
#  60908 accuracy: 0.74937544611
#   -0.001 ('throat', 'N')==True and label is 'pos'
#   -0.001 ('sad.', 'NP')==True and label is 'pos'
#   -0.001 ('welcom', 'PRO')==True and label is 'neg'
#   -0.001 ('stuck', 'ADJ')==True and label is 'pos'
#   -0.000 ('disappoint', 'ADJ')==True and label is 'pos'
#   -0.000 ('hayfev', 'N')==True and label is 'pos'
# ...

# %%
#input
import pandas as pd
import nltk
from nltk.corpus import treebank
x_test = []
y_test = []
p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
print len(p_test)
p_test.SentimentText
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
# Out:
# 60908

# %% [markdown]
# ## Cleaned Data Naive Bayes

# %%
#input
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
def word_feats(words):
    return dict([(word, True) for word in words])

l = []
for f in range(len(p_test)):
    if p_test.Sentiment[f] == 0:
        l.append(f)

p = []
for f in range(len(p_test)):
    if p_test.Sentiment[f] == 1:
        p.append(f)        
print len(l)
print len(p)
# Out:
# 30592
# 30316

# %%
stop_words = []
import re

def clean_data(l):
    d = []
    for i in l:
        if i.startswith('http'):
            d.append('URL')
        elif i.startswith('@'):
            d.append('USERNAME')
        else:
            
            d.append(re.sub(r'([a-z]+?)\1+', r'\1\1', i))
    return d
            
negfeats = [(word_feats(x for x in clean_data(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'neg') for f in l]
posfeats = [(word_feats(x for x in clean_data(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'pos') for f in p]

trainfeats = negfeats+ posfeats
print len(trainfeats)

import random 
random.shuffle(trainfeats)
print(len(trainfeats))


p_train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')

l_t = []
for f in range(len(p_train)):
    if p_train.Sentiment[f] == 0:
        l_t.append(f)

p_t = []
for f in range(len(p_train)):
    if p_train.Sentiment[f] == 1:
        p_t.append(f)        
print len(l_t)
print len(p_t)
# Out:
# 60908
# 60908
# 22606
# 22226

# %%
stop_words = []
negfeatstest = [(word_feats(x for x in clean_data(p_train.SentimentText[f].lower().split()) if x not in stop_words), 'neg') for f in l_t]
posfeatstest = [(word_feats(x for x in clean_data(p_train.SentimentText[f].lower().split()) if x not in stop_words), 'pos') for f in p_t]

testfeats = negfeatstest + posfeatstest
points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
output2 = []
for i in points:
    
    classifier = NaiveBayesClassifier.train(trainfeats[:i])
    out = nltk.classify.util.accuracy(classifier, testfeats)
    output2.append(out)
    if i !=60908:
        del classifier
    print 'dataset: ',i, 'accuracy:', out



classifier.show_most_informative_features()

del classifier
# Out:
# dataset:  10 accuracy: 0.550678087081
# dataset:
#  50 accuracy: 0.586032298358
# dataset:
#  100 accuracy: 0.603742862241
# dataset:
#  500 accuracy: 0.638227159172
# dataset:
#  1000 accuracy: 0.668027301927
# dataset:
#  5000 accuracy: 0.702980014276
# dataset:
#  10000 accuracy: 0.717523197716
# dataset:
#  15000 accuracy: 0.721448965025
# dataset:
#  20000 accuracy: 0.723746431121
# dataset:
#  25000 accuracy: 0.728363668808
# dataset:
#  30000 accuracy: 0.732936295503
# dataset:
#  35000 accuracy: 0.735033012134
# dataset:
#  40000 accuracy: 0.736125981442
# dataset:
#  45000 accuracy: 0.738245003569
# dataset:
#  50000 accuracy: 0.739538722341
# dataset:
#  55000 accuracy: 0.741434689507
# dataset:
#  60000 accuracy: 0.743732155603
# dataset:
#  60908 accuracy: 0.743843683084
# Most Informative Features
#                   throat = True              neg : pos    =     52.5 : 1.0
#                     sad. = True              neg : pos    =     47.0 : 1.0
# ...

# %%
from ipy_table import *
data_table = [
    ['Training Size', 'Navie Bayes with data cleaned', 'Naive Bayes with cleaned data \nwith repeats removed'],
    ];
for i in range(len(output1)) :
    data_table.append([points[i],output1[i],output2[i]])

make_table(data_table)
apply_theme('basic')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Training&nbspSize</b></td><td  style="background-color:LightGray;"><b>Navie&nbspBayes&nbspwith&nbspdata&nbspcleaned</b></td><td  style="background-color:LightGray;"><b>Naive&nbspBayes&nbspwith&nbspcleaned&nbspdata&nbsp
# ...

# %%
import nltk.classify.util
from nltk.classify import MaxentClassifier
algorithm = nltk.classify.MaxentClassifier.ALGORITHMS[0]

points_3 = [60908]
amax = []
for i in points_3:
    classifier = nltk.MaxentClassifier.train(trainfeats[:i],algorithm, max_iter=20)
    out_maxent_uni = nltk.classify.util.accuracy(classifier, testfeats)
    amax.append(out_maxent_uni)
    print 'dataset: ',i, 'accuracy:', out_maxent_uni
classifier.show_most_informative_features()
del classifier
# Out:
#   ==> Training (20 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.498
#              2          -0.69313        0.861
#              3          -0.69311        0.861
#              4          -0.69309        0.861
#              5          -0.69308        0.861
#              6          -0.69306        0.861
#              7          -0.69304        0.861
#              8          -0.69302        0.861
#              9          -0.69301        0.861
#             10          -0.69299        0.861
#             11          -0.69297        0.862
#             12          -0.69295        0.862
#             13          -0.69294        0.862
#             14          -0.69292        0.862
#             15          -0.69290        0.862
#             16          -0.69288        0.862
#             17          -0.69287        0.862
#             18          -0.69285        0.862
# ...

# %%
import nltk.classify.util
from nltk.classify import MaxentClassifier
algorithm = nltk.classify.MaxentClassifier.ALGORITHMS[1]

points_3 = [60908]
amax2 = []
for i in points_3:
    classifier = nltk.MaxentClassifier.train(trainfeats[:i],algorithm, max_iter=20)
    out_maxent_uni = nltk.classify.util.accuracy(classifier, testfeats)
    amax2.append(out_maxent_uni)
    print 'dataset: ',i, 'accuracy:', out_maxent_uni
classifier.show_most_informative_features()
del classifier
# Out:
#   ==> Training (20 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.498
#              2          -0.59550        0.865
#              3          -0.52745        0.884
#              4          -0.47757        0.892
#              5          -0.43944        0.898
#              6          -0.40922        0.903
#              7          -0.38456        0.908
#              8          -0.36395        0.912
#              9          -0.34640        0.915
#             10          -0.33122        0.918
#             11          -0.31791        0.922
#             12          -0.30613        0.924
#             13          -0.29559        0.926
#             14          -0.28610        0.928
#             15          -0.27749        0.930
#             16          -0.26962        0.932
#             17          -0.26241        0.933
#             18          -0.25576        0.935
# ...

# %%
points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy1 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeats[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeats)
    if i !=60908:
        del classif
    accuracy1.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.557882762313
# .
# dataset:  50 accuracy: 0.605125802998
# .
# dataset:  100 accuracy: 0.612040506781
# .
# dataset:  500 accuracy: 0.635260528194
# .
# dataset:  1000 accuracy: 0.67369289793
# .
# dataset:  5000 accuracy: 0.721315132049
# .
# dataset:  10000 accuracy: 0.738445753034
# .
# dataset:  15000 accuracy: 0.75
# .
# dataset:  20000 accuracy: 0.754371877231
# .
# dataset:  25000 accuracy: 0.758743754461
# .
# dataset:  30000 accuracy: 0.762580299786
# .
# dataset:  35000 accuracy: 0.766149179158
# .
# dataset:  40000 accuracy: 0.76795592434
# .
# dataset:  45000 accuracy: 0.769896502498
# .
# dataset:  50000 accuracy: 0.772417023555
# .
# dataset:  55000 accuracy: 0.774580656674
# .
# dataset:  60000 accuracy: 0.775896680942
# .
# dataset:  60908 accuracy: 0.776231263383

# %%
import pandas as pd
import nltk
import scipy as sp
from nltk.classify import NaiveBayesClassifier
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
from nltk.tag.simplify import simplify_wsj_tag

p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')
train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
stopwords = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv')

def word_feats(words):
    return dict([(word, True) for word in words])


for i in range(len(train)):
    t = []
    for word in nltk.word_tokenize(train.SentimentText[i]):
        t.append(stemmer.stem(word))
    k = clean_data(t)
    train.SentimentText[i] = " ".join(k)
neg_tw = []
pos_tw = []
for i in range(len(train)):
    if train.Sentiment[i] == 0:
        neg_tw.append(i)
    else:
        pos_tw.append(i)
    
    
negfeatspos = []
posfeatspos = []
for f in range(len(train)):
    if f in neg_tw:
        negfeatspos.append((word_feats(x for x in train.SentimentText[f].lower().split() if x not in stop_words), 'neg') )
    else:
        posfeatspos.append((word_feats(x for x in train.SentimentText[f].lower().split() if x not in stop_words), 'pos') )
    
trainfeatspos = negfeatspos+ posfeatspos
print len(trainfeatspos)

import random 
new_train = random.shuffle(trainfeatspos)

for i in range(len(p_test)):
    t = []
    for word in nltk.word_tokenize(p_test.SentimentText[i]):
        t.append(stemmer.stem(word))
    k = clean_data(t)
    p_test.SentimentText[i] = " ".join(k)
neg_tweets_test = []
pos_tweets_test = []
for i in range(len(p_test)):
    if p_test.Sentiment[i] ==0:
        neg_tweets_test.append(i)
    else:
        pos_tweets_test.append(i)

#negfeatstestpos = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'neg') for f in neg_tweets_test]
#posfeatstest = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'pos') for f in pos_tweets_test]
negfeatstestpos = []
posfeatstestpos = []
for f in range(len(p_test)):
    if f in neg_tweets_test:
        negfeatstestpos.append((word_feats(x for x in p_test.SentimentText[f].lower().split() if x not in stop_words), 'neg')) 
    else:
        posfeatstestpos.append((word_feats(x for x in p_test.SentimentText[f].lower().split() if x not in stop_words), 'pos') )
    
testfeatspos = negfeatstestpos + posfeatstestpos
random.shuffle(testfeatspos)
print len(testfeatspos)
# Out:
# 60908
# 44832

# %%
trainfeattrue = []
for a in trainfeatspos:
    trainfeattrue.append((dict((k,True) for k in a[0]), a[1]))
    
testfeattrue = []
for a in testfeatspos:
    testfeattrue.append((dict((k,True) for k in a[0]), a[1]))

points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy3 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeattrue[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeattrue)
    if i !=60908:
        del classif
    accuracy3.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.497301034975
# .
# dataset:  50 accuracy: 0.58460474661
# .
# dataset:  100 accuracy: 0.597541934333
# .
# dataset:  500 accuracy: 0.659461991435
# .
# dataset:  1000 accuracy: 0.688325303355
# .
# dataset:  5000 accuracy: 0.738289614561
# .
# dataset:  10000 accuracy: 0.754974125625
# .
# dataset:  15000 accuracy: 0.760528194147
# .
# dataset:  20000 accuracy: 0.765747680228
# .
# dataset:  25000 accuracy: 0.770030335475
# .
# dataset:  30000 accuracy: 0.772260885082
# .
# dataset:  35000 accuracy: 0.773532298358
# .
# dataset:  40000 accuracy: 0.775762847966
# .
# dataset:  45000 accuracy: 0.776967344754
# .
# dataset:  50000 accuracy: 0.778617951463
# .
# dataset:  55000 accuracy: 0.780759279086
# .
# dataset:  60000 accuracy: 0.781205389008
# .
# dataset:  60908 accuracy: 0.781004639543

# %%
# Out:
# ([('username', 'N'),
#   ('addicted2iphon', 'NP'),
#   ('wait', 'N'),
#   ('for', 'P'),
#   ('jailbreak', 'N'),
#   ('also.', 'NP'),
#   ('oh', 'N'),
#   ('pooh', 'N')],
#  'neg')

# %%
len(p_test)
# Out:
# 44832

# %%
p_test.SentimentText[0]
# Out:
# "USERNAME SchoolBoyQ L0l uhm ; you need to just wife up mari jane cuz that 's all you talk about !"

# %%
import pandas as pd
import nltk
import scipy as sp
from nltk.classify import NaiveBayesClassifier
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
from nltk.tag.simplify import simplify_wsj_tag

def find_bigrams(input_list):
  bigram_list = []
  for i in range(len(input_list)-1):
      bigram_list.append((input_list[i], input_list[i+1]))
  return bigram_list

p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')
train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
stopwords = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv')

def word_feats(words):
    return dict([(word, True) for word in words])


for i in range(len(train)):
    t = []
    for word in nltk.word_tokenize(train.SentimentText[i]):
        t.append(stemmer.stem(word))
    k = clean_data(t)
    train.SentimentText[i] = " ".join(k)
neg_tw = []
pos_tw = []
for i in range(len(train)):
    if train.Sentiment[i] == 0:
        neg_tw.append(i)
    else:
        pos_tw.append(i)
    
    
negfeatspos = []
posfeatspos = []
for f in range(len(train)):
    if f in neg_tw:
        negfeatspos.append((word_feats(x for x in train.SentimentText[f].lower().split()+ find_bigrams(train.SentimentText[f].lower().split()) if x not in stop_words), 'neg') )
    else:
        posfeatspos.append((word_feats(x for x in train.SentimentText[f].lower().split()+ find_bigrams(train.SentimentText[f].lower().split()) if x not in stop_words), 'pos') )
    
trainfeatspos = negfeatspos+ posfeatspos
print len(trainfeatspos)

import random 
new_train = random.shuffle(trainfeatspos)

for i in range(len(p_test)):
    t = []
    for word in nltk.word_tokenize(p_test.SentimentText[i]):
        t.append(stemmer.stem(word))
    k = clean_data(t)
    p_test.SentimentText[i] = " ".join(k)
neg_tweets_test = []
pos_tweets_test = []
for i in range(len(p_test)):
    if p_test.Sentiment[i] ==0:
        neg_tweets_test.append(i)
    else:
        pos_tweets_test.append(i)

#negfeatstestpos = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'neg') for f in neg_tweets_test]
#posfeatstest = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'pos') for f in pos_tweets_test]
negfeatstestpos = []
posfeatstestpos = []
for f in range(len(p_test)):
    if f in neg_tweets_test:
        negfeatstestpos.append((word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'neg')) 
    else:
        posfeatstestpos.append((word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'pos') )
    
testfeatspos = negfeatstestpos + posfeatstestpos
random.shuffle(testfeatspos)
print len(testfeatspos)
# Out:
# 60908
# 44832

# %%
trainfeattrue = []
for a in trainfeatspos:
    trainfeattrue.append((dict((k,True) for k in a[0]), a[1]))
    
testfeattrue = []
for a in testfeatspos:
    testfeattrue.append((dict((k,True) for k in a[0]), a[1]))

points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy3 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeattrue[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeattrue)
    if i !=60908:
        del classif
    accuracy3.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.517665952891
# .
# dataset:  50 accuracy: 0.526655067809
# .
# dataset:  100 accuracy: 0.576262491078
# .
# dataset:  500 accuracy: 0.672934511064
# .
# dataset:  1000 accuracy: 0.694013204854
# .
# dataset:  5000 accuracy: 0.739248750892
# .
# dataset:  10000 accuracy: 0.757115453248
# .
# dataset:  15000 accuracy: 0.76670681656
# .
# dataset:  20000 accuracy: 0.773063882941
# .
# dataset:  25000 accuracy: 0.778261063526
# .
# dataset:  30000 accuracy: 0.780915417559
# .
# dataset:  35000 accuracy: 0.783592077088
# .
# dataset:  40000 accuracy: 0.786737152034
# .
# dataset:  45000 accuracy: 0.789614561028
# .
# dataset:  50000 accuracy: 0.790952890792
# .
# dataset:  55000 accuracy: 0.792135082084
# .
# dataset:  60000 accuracy: 0.794097965739
# .
# dataset:  60908 accuracy: 0.793674161313

# %%
slang_file = open("/Users/girish.kathalagiri/Personal/twittersentiment/data/slang.txt")
slang_dict = {}
e = slang_file.readlines()
for i in e:
    w = i.split(" - ")
    #print len(w)
    slang_dict[w[0].strip()] = w[1].strip()

# %%
import pandas as pd
import nltk
import scipy as sp
from nltk.classify import NaiveBayesClassifier
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
from nltk.tag.simplify import simplify_wsj_tag

def find_bigrams(input_list):
  bigram_list = []
  for i in range(len(input_list)-1):
      bigram_list.append((input_list[i], input_list[i+1]))
  return bigram_list

p_test = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TestSA.csv')
train = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/TrainSA.csv')
stopwords = pd.read_csv('/Users/girish.kathalagiri/Personal/twittersentiment/data/stop_words.csv')

def word_feats(words):
    return dict([(word, True) for word in words])


for i in range(len(train)):
    t = []
    for word in nltk.word_tokenize(train.SentimentText[i]):
        t.append(stemmer.stem(word))
    d = []
    for st in t:
        if st in slang_dict.keys():
            #sys.stdout.write('.')
            st = slang_dict[st]
        
        d.append(st)
    k = clean_data(d)
    train.SentimentText[i] = " ".join(k)
neg_tw = []
pos_tw = []
for i in range(len(train)):
    if train.Sentiment[i] == 0:
        neg_tw.append(i)
    else:
        pos_tw.append(i)
    
    
negfeatspos = []
posfeatspos = []
for f in range(len(train)):
    if f in neg_tw:
        negfeatspos.append((word_feats(x for x in train.SentimentText[f].lower().split()+ find_bigrams(train.SentimentText[f].lower().split()) if x not in stop_words), 'neg') )
    else:
        posfeatspos.append((word_feats(x for x in train.SentimentText[f].lower().split()+ find_bigrams(train.SentimentText[f].lower().split()) if x not in stop_words), 'pos') )
    
trainfeatspos = negfeatspos+ posfeatspos
print len(trainfeatspos)

import random 
new_train = random.shuffle(trainfeatspos)

for i in range(len(p_test)):
    t = []
    for word in nltk.word_tokenize(p_test.SentimentText[i]):
        t.append(stemmer.stem(word))
    d = []
    for st in t:
        if st in slang_dict.keys():
            #sys.stdout.write('.')
            st = slang_dict[st]
        
        d.append(st)
    try:
        k = clean_data(d)
    except:
        print i + " === " + d
        
    k = clean_data(d)
    p_test.SentimentText[i] = " ".join(k)
neg_tweets_test = []
pos_tweets_test = []
for i in range(len(p_test)):
    if p_test.Sentiment[i] ==0:
        neg_tweets_test.append(i)
    else:
        pos_tweets_test.append(i)

#negfeatstestpos = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'neg') for f in neg_tweets_test]
#posfeatstest = [(word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stopwords), 'pos') for f in pos_tweets_test]
negfeatstestpos = []
posfeatstestpos = []
for f in range(len(p_test)):
    if f in neg_tweets_test:
        negfeatstestpos.append((word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'neg')) 
    else:
        posfeatstestpos.append((word_feats(x for x in p_test.SentimentText[f].lower().split() + find_bigrams(p_test.SentimentText[f].lower().split()) if x not in stop_words), 'pos') )
    
testfeatspos = negfeatstestpos + posfeatstestpos
random.shuffle(testfeatspos)
print len(testfeatspos)
# Out:
# 60908
# 44832

# %%
trainfeattrue = []
for a in trainfeatspos:
    trainfeattrue.append((dict((k,True) for k in a[0]), a[1]))
    
testfeattrue = []
for a in testfeatspos:
    testfeattrue.append((dict((k,True) for k in a[0]), a[1]))

points = [10,50,100,500,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,55000,60000,60908]
from sklearn.svm import LinearSVC
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.svm import LinearSVC
accuracy3 = []
for i in points:
    
    classif = SklearnClassifier(LinearSVC(C=0.032))
    classif.train(trainfeattrue[:i])
    #print 'train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats))
    out = nltk.classify.util.accuracy(classif, testfeattrue)
    if i !=60908:
        del classif
    accuracy3.append(out)
    import sys
    sys.stdout.write('.')
    print 'dataset: ',i, 'accuracy:', out
# Out:
# .dataset:  10 accuracy: 0.559310314061
# .
# dataset:  50 accuracy: 0.60278372591
# .
# dataset:  100 accuracy: 0.629706459672
# .
# dataset:  500 accuracy: 0.678555496074
# .
# dataset:  1000 accuracy: 0.695507673091
# .
# dataset:  5000 accuracy: 0.741903104925
# .
# dataset:  10000 accuracy: 0.757918451106
# .
# dataset:  15000 accuracy: 0.769606531049
# .
# dataset:  20000 accuracy: 0.774536045682
# .
# dataset:  25000 accuracy: 0.777971092077
# .
# dataset:  30000 accuracy: 0.781183083512
# .
# dataset:  35000 accuracy: 0.783458244111
# .
# dataset:  40000 accuracy: 0.785956459672
# .
# dataset:  45000 accuracy: 0.786848679515
# .
# dataset:  50000 accuracy: 0.789213062099
# .
# dataset:  55000 accuracy: 0.791733583155
# .
# dataset:  60000 accuracy: 0.792938079943
# .
# dataset:  60908 accuracy: 0.792848857959

# %%
t = 0.0
t = (float)(7589092.0/20952530.0)
print t
# Out:
# 0.362204087048
